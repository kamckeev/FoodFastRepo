# %%
# Dependencies
import requests
import json
import pandas as pd
from pandas.io.json import json_normalize 

# Google developer API key
from config import gkey

# %%
 # geocoordinates
    #center-point: William Peace University
    # 35.7895° N, 78.6374° W
target_coordinates = "35.7895, -78.6374"
target_search = "fast+food"
#20mi radius
target_radius = 40000
target_type = "restaurant"

# set up a parameters dictionary
params = {
    "location": target_coordinates,
    "keyword": target_search,
    "radius": target_radius,
    "type": target_type,
    "key": gkey
}

# base url
base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

# run a request using our params dictionary
response = requests.get(base_url, params=params)

# %%
 # print the response url, avoid doing for public github repos in order to avoid exposing key
# print(response.url)

# %%
ff_data = response.json()

# # # Print the json (pretty printed)
# data=(json.dumps(ff_data, sort_keys=True))
# data
df=json_normalize(ff_data,'results')
# df = json_normalize(d, 'abc')
print (df)
# Out:
#                                              geometry  \
# 0   {'location': {'lat': 35.81912459999999, 'lng':...
# 1   {'location': {'lat': 35.7724071, 'lng': -78.63...
# 2   {'location': {'lat': 35.7883316, 'lng': -78.64...
# 3   {'location': {'lat': 35.776055, 'lng': -78.768...
# 4   {'location': {'lat': 35.7844859, 'lng': -78.68...
# 5   {'location': {'lat': 35.818479, 'lng': -78.625...
# 6   {'location': {'lat': 35.8192595, 'lng': -78.90...
# 7   {'location': {'lat': 35.785243, 'lng': -78.687...
# 8   {'location': {'lat': 35.9668836, 'lng': -78.95...
# 9   {'location': {'lat': 35.8374723, 'lng': -78.61...
# 10  {'location': {'lat': 35.8368341, 'lng': -78.64...
# 11  {'location': {'lat': 35.7905899, 'lng': -78.66...
# 12  {'location': {'lat': 35.7981176, 'lng': -78.57...
# 13  {'location': {'lat': 35.7926058, 'lng': -78.68...
# 14  {'location': {'lat': 35.7445182, 'lng': -78.82...
# 15  {'location': {'lat': 35.8053497, 'lng': -78.81...
# 16  {'location': {'lat': 35.860819, 'lng': -78.597...
# 17  {'location': {'lat': 35.8160958, 'lng': -78.69...
# 18  {'location': {'lat': 35.7041788, 'lng': -78.79...
# 19  {'location': {'lat': 35.7912015, 'lng': -78.65...
#
#                                                  icon  \
# 0   https://maps.gstatic.com/mapfiles/place_api/ic...
# 1   https://maps.gstatic.com/mapfiles/place_api/ic...
# 2   https://maps.gstatic.com/mapfiles/place_api/ic...
# 3   https://maps.gstatic.com/mapfiles/place_api/ic...
# 4   https://maps.gstatic.com/mapfiles/place_api/ic...
# 5   https://maps.gstatic.com/mapfiles/place_api/ic...
# 6   https://maps.gstatic.com/mapfiles/place_api/ic...
# 7   https://maps.gstatic.com/mapfiles/place_api/ic...
# 8   https://maps.gstatic.com/mapfiles/place_api/ic...
# 9   https://maps.gstatic.com/mapfiles/place_api/ic...
# 10  https://maps.gstatic.com/mapfiles/place_api/ic...
# 11  https://maps.gstatic.com/mapfiles/place_api/ic...
# 12  https://maps.gstatic.com/mapfiles/place_api/ic...
# 13  https://maps.gstatic.com/mapfiles/place_api/ic...
# 14  https://maps.gstatic.com/mapfiles/place_api/ic...
# 15  https://maps.gstatic.com/mapfiles/place_api/ic...
# 16  https://maps.gstatic.com/mapfiles/place_api/ic...
# 17  https://maps.gstatic.com/mapfiles/place_api/ic...
# 18  https://maps.gstatic.com/mapfiles/place_api/ic...
# 19  https://maps.gstatic.com/mapfiles/place_api/ic...
#
#                                           id                       name  \
# 0   7a400c278d97b06abf61e3420df1ef8316b52dcd                 McDonald's
# 1   8c27c6b4eea555fe94ee9b5831d72d12d868e5cb                 McDonald's
# 2   870b41546dba81d5b4ded96568e1eee6186f35b4                 McDonald's
# 3   f3ebd0ed589a403e9911513c4dd58267df0ba0e7  Dairy Queen Grill & Chill
# 4   6adec02ca4e8fb14ef2c0a9024a22a004ef51831                    Wendy's
# 5   834c5f3c0ef2931089d7d26de323d18740088a3b                     Arby's
# 6   ef6c81b696b2af21f7cb9c01675a5f10e77b3af7                 McDonald's
# 7   3d4fe1dec43faa8ad4947a8cd8ee59631bbb3eb7                 McDonald's
# 8   1465c835ec7685e2134bd0875ab0907cb0fa0d82                   Cook Out
# 9   9f16e837344c8fe18efd36e0c0a80371a15c63a6                    Wendy's
# 10  d6f111248d8c338e9eaba658b313817231009f88                Chick-fil-A
# 11  ca01ecbc26626f8e2746558cc7429fbeda58187d                 McDonald's
# 12  a0ebfa486a45729bd205f475a3d4769b9de1ce4f                    Wendy's
# 13  02a503c03030294cbf5c75db1397c2ca09ef9698                     Arby's
# 14  d3ddbf6fad892b9aa4756ddca683637680f8c7dd                 McDonald's
# 15  276ec85e89c4b7ca708726852e7c31aa9937fca6                    Wendy's
# 16  eb5849a4fdffe55a775a57780798c4b73c350524   Snoopy's Hot Dogs & More
# 17  3179addb85db1226ab884f9f2c7d0a2ce4277807                Chick-fil-A
# 18  0980fb3fb7e5e44af62a8b8fa5fae1758d3d25ed                 McDonald's
# 19  631236845d47a97019004a18cafddae6d73d5e64                Chick-fil-A
#
#          opening_hours                                             photos  \
# 0   {'open_now': True}  [{'height': 768, 'html_attributions': ['<a hre...
# 1   {'open_now': True}  [{'height': 768, 'html_attributions': ['<a hre...
# 2   {'open_now': True}  [{'height': 768, 'html_attributions': ['<a hre...
# 3   {'open_now': True}  [{'height': 3984, 'html_attributions': ['<a hr...
# 4   {'open_now': True}  [{'height': 4032, 'html_attributions': ['<a hr...
# 5   {'open_now': True}  [{'height': 4032, 'html_attributions': ['<a hr...
# 6   {'open_now': True}  [{'height': 768, 'html_attributions': ['<a hre...
# 7   {'open_now': True}  [{'height': 768, 'html_attributions': ['<a hre...
# 8   {'open_now': True}  [{'height': 3840, 'html_attributions': ['<a hr...
# 9   {'open_now': True}  [{'height': 459, 'html_attributions': ['<a hre...
# 10  {'open_now': True}  [{'height': 500, 'html_attributions': ['<a hre...
# 11  {'open_now': True}  [{'height': 768, 'html_attributions': ['<a hre...
# 12  {'open_now': True}  [{'height': 5344, 'html_attributions': ['<a hr...
# 13  {'open_now': True}  [{'height': 1080, 'html_attributions': ['<a hr...
# 14  {'open_now': True}  [{'height': 768, 'html_attributions': ['<a hre...
# 15  {'open_now': True}  [{'height': 459, 'html_attributions': ['<a hre...
# 16  {'open_now': True}  [{'height': 2560, 'html_attributions': ['<a hr...
# 17  {'open_now': True}  [{'height': 4048, 'html_attributions': ['<a hr...
# 18  {'open_now': True}  [{'height': 768, 'html_attributions': ['<a hre...
# 19  {'open_now': True}  [{'height': 500, 'html_attributions': ['<a hre...
#
#                        place_id  \
# 0   ChIJcxVnXv1YrIkRf_iPbp6fQ_M
# 1   ChIJT63WdHRfrIkRG1TJz7--NHM
# 2   ChIJhQBPbWdfrIkRZIcZWwyzMxk
# 3   ChIJ56XklXDzrIkRYP90XZlqkRU
# 4   ChIJCbqPArv1rIkREXoptEFTddg
# 5   ChIJgXowl89YrIkRaW5xgCnfCp8
# 6   ChIJp5VZHzzsrIkR0m6gAEHLoRc
# 7   ChIJV9iaqrv1rIkRSrKjooXe96Q
# 8   ChIJC2tsBl_mrIkR6ZszZSBsn8g
# 9   ChIJrWku-OJYrIkRjQHJWXk7GHI
# 10  ChIJ_8BCxpZYrIkR0xy6xdDECws
# 11  ChIJuYmnmIz1rIkROgEGbxexXwg
# 12  ChIJPaNrYq5erIkRTY09pBnfEaY
# 13  ChIJva8uQ7_1rIkRQPcaDMnBn5E
# 14  ChIJdQVE1p2SrIkRtqpAt7yOV6g
# 15  ChIJZa7zez_yrIkRNcXT3k10Udw
# 16  ChIJ9_FBpbpZrIkR6ThypqMPJMw
# 17  ChIJe8JlZXj2rIkRDDZgShqNM30
# 18  ChIJnWfO_QKNrIkRZYAe88leavg
# 19  ChIJIbsNcpL1rIkRYZOopluU4r0
#
#                                             plus_code  price_level  rating  \
# 0   {'compound_code': 'R99G+J3 Raleigh, North Caro...          1.0     3.0
# 1   {'compound_code': 'Q9C6+XR Raleigh, North Caro...          1.0     3.2
# 2   {'compound_code': 'Q9Q2+89 Raleigh, North Caro...          1.0     3.5
# 3   {'compound_code': 'Q6GJ+CQ Cary, North Carolin...          1.0     4.2
# 4   {'compound_code': 'Q8M7+Q2 Raleigh, North Caro...          1.0     3.3
# 5   {'compound_code': 'R99F+9W Raleigh, North Caro...          1.0     4.1
# 6   {'compound_code': 'R39X+P6 Cary, North Carolin...          1.0     2.9
# 7   {'compound_code': 'Q8P6+3R Raleigh, North Caro...          1.0     2.9
# 8   {'compound_code': 'X28W+Q5 Durham, North Carol...          1.0     4.1
# 9   {'compound_code': 'R9PP+XG Raleigh, North Caro...          1.0     3.5
# 10  {'compound_code': 'R9P5+P5 Raleigh, North Caro...          1.0     4.5
# 11  {'compound_code': 'Q8RP+6X Raleigh, North Caro...          1.0     3.2
# 12  {'compound_code': 'QCXF+63 Raleigh, North Caro...          1.0     3.5
# 13  {'compound_code': 'Q8V8+2G Raleigh, North Caro...          1.0     4.0
# 14  {'compound_code': 'P5VH+R8 Apex, White Oak, NC...          1.0     3.5
# 15  {'compound_code': 'R54Q+43 Morrisville, Cedar ...          1.0     3.6
# 16  {'compound_code': 'VC62+8R Raleigh, North Caro...          NaN     4.5
# 17  {'compound_code': 'R884+CR Raleigh, North Caro...          1.0     4.7
# 18  {'compound_code': 'P633+MP Cary, North Carolin...          1.0     3.4
# 19  {'compound_code': 'Q8RR+F9 Raleigh, North Caro...          1.0     4.3
#
#                       reference   scope  \
# 0   ChIJcxVnXv1YrIkRf_iPbp6fQ_M  GOOGLE
# 1   ChIJT63WdHRfrIkRG1TJz7--NHM  GOOGLE
# 2   ChIJhQBPbWdfrIkRZIcZWwyzMxk  GOOGLE
# 3   ChIJ56XklXDzrIkRYP90XZlqkRU  GOOGLE
# 4   ChIJCbqPArv1rIkREXoptEFTddg  GOOGLE
# 5   ChIJgXowl89YrIkRaW5xgCnfCp8  GOOGLE
# 6   ChIJp5VZHzzsrIkR0m6gAEHLoRc  GOOGLE
# 7   ChIJV9iaqrv1rIkRSrKjooXe96Q  GOOGLE
# 8   ChIJC2tsBl_mrIkR6ZszZSBsn8g  GOOGLE
# 9   ChIJrWku-OJYrIkRjQHJWXk7GHI  GOOGLE
# 10  ChIJ_8BCxpZYrIkR0xy6xdDECws  GOOGLE
# 11  ChIJuYmnmIz1rIkROgEGbxexXwg  GOOGLE
# 12  ChIJPaNrYq5erIkRTY09pBnfEaY  GOOGLE
# 13  ChIJva8uQ7_1rIkRQPcaDMnBn5E  GOOGLE
# 14  ChIJdQVE1p2SrIkRtqpAt7yOV6g     NaN
# 15  ChIJZa7zez_yrIkRNcXT3k10Udw  GOOGLE
# 16  ChIJ9_FBpbpZrIkR6ThypqMPJMw     NaN
# 17  ChIJe8JlZXj2rIkRDDZgShqNM30  GOOGLE
# 18  ChIJnWfO_QKNrIkRZYAe88leavg  GOOGLE
# 19  ChIJIbsNcpL1rIkRYZOopluU4r0  GOOGLE
#
#                                                 types  user_ratings_total  \
# 0   [cafe, restaurant, food, store, point_of_inter...                 394
# 1   [cafe, restaurant, food, store, point_of_inter...                1012
# 2   [cafe, restaurant, food, store, point_of_inter...                 464
# 3   [restaurant, food, store, point_of_interest, e...                 349
# 4   [restaurant, food, point_of_interest, establis...                 932
# 5   [restaurant, food, point_of_interest, establis...                 304
# 6   [cafe, restaurant, food, store, point_of_inter...                 284
# 7   [cafe, restaurant, food, store, point_of_inter...                 931
# 8   [restaurant, food, point_of_interest, establis...                1154
# 9   [restaurant, food, point_of_interest, establis...                 523
# 10  [restaurant, food, point_of_interest, establis...                 330
# 11  [cafe, restaurant, food, store, point_of_inter...                 338
# 12  [restaurant, food, point_of_interest, establis...                 653
# 13  [restaurant, food, point_of_interest, establis...                 303
# 14  [cafe, restaurant, food, store, point_of_inter...                 216
# 15  [restaurant, food, point_of_interest, establis...                 269
# 16  [restaurant, food, point_of_interest, establis...                 210
# 17  [restaurant, food, point_of_interest, establis...                 610
# 18  [cafe, restaurant, food, store, point_of_inter...                 339
# 19  [restaurant, food, point_of_interest, establis...                 563
#
#                                           vicinity
# 0                 2801 Old Wake Forest Rd, Raleigh
# 1                          105 E South St, Raleigh
# 2                          703 W Peace St, Raleigh
# 3                              631 Walnut St, Cary
# 4                       3715 Western Blvd, Raleigh
# 5                     2601 Wake Forest Rd, Raleigh
# 6                        4980 Cary Glen Blvd, Cary
# 7                       3710 Western Blvd, Raleigh
# 8                          3119 Shannon Rd, Durham
# 9                     4105 Wake Forest Rd, Raleigh
# 10  4154 Main at North Hills St Suite 114, Raleigh
# 11                         416 Oberlin Rd, Raleigh
# 12                      3701 New Bern Ave, Raleigh
# 13                   3415 Hillsborough St, Raleigh
# 14                                 900 US-64, Apex
# 15                  2007 NW Cary Pkwy, Morrisville
# 16                  2431 Spring Forest Rd, Raleigh
# 17                  3770 Lake Boone Trail, Raleigh
# 18                     3494 Kildaire Farm Rd, Cary
# 19                        2000 Cameron St, Raleigh

# %%
df_test = response.json()
# print(df_test['results'])
df_test = pd.DataFrame(df_test['results'])

# print(df_test)

print(df_test[:0]) # column names
# Out:
# Empty DataFrame
# Columns: [geometry, icon, id, name, opening_hours, photos, place_id, plus_code, price_level, rating, reference, scope, types, user_ratings_total, vicinity]
# Index: []

# %%
# ff_df = pd.concat([pd.DataFrame(v) for k,v in ff_data.items()])
# print (df)

# %%
print(df_test.loc[0,])
# Out:
# geometry              {'location': {'lat': 35.81912459999999, 'lng':...
# icon                  https://maps.gstatic.com/mapfiles/place_api/ic...
# id                             7a400c278d97b06abf61e3420df1ef8316b52dcd
# name                                                         McDonald's
# opening_hours                                        {'open_now': True}
# photos                [{'height': 768, 'html_attributions': ['<a hre...
# place_id                                    ChIJcxVnXv1YrIkRf_iPbp6fQ_M
# plus_code             {'compound_code': 'R99G+J3 Raleigh, North Caro...
# price_level                                                           1
# rating                                                                3
# reference                                   ChIJcxVnXv1YrIkRf_iPbp6fQ_M
# scope                                                            GOOGLE
# types                 [cafe, restaurant, food, store, point_of_inter...
# user_ratings_total                                                  394
# vicinity                               2801 Old Wake Forest Rd, Raleigh
# Name: 0, dtype: object

# %%
#print(df_test.loc[i,'geometry']['location'])
