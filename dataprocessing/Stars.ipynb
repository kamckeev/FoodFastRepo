# %%
import json
import pandas as pd
import numpy as np
import itertools

jsonfile_path = "business.json"

json_data = [json.loads(line) for line in open("business.json", encoding = "utf8")]
json_data[3]
# Out:
# {'business_id': 'xvX2CttrVhyG2z1dFg_0xw',
#  'name': 'Farmers Insurance - Paul Lorenz',
#  'address': '15655 W Roosevelt St, Ste 237',
#  'city': 'Goodyear',
#  'state': 'AZ',
#  'postal_code': '85338',
#  'latitude': 33.4556129678,
#  'longitude': -112.3955963552,
#  'stars': 5.0,
#  'review_count': 3,
#  'is_open': 1,
#  'attributes': None,
#  'categories': 'Insurance, Financial Services',
#  'hours': {'Monday': '8:0-17:0',
#   'Tuesday': '8:0-17:0',
#   'Wednesday': '8:0-17:0',
#   'Thursday': '8:0-17:0',
#   'Friday': '8:0-17:0'}}

# %%
yelp_df=pd.DataFrame(json_data)
yelp_df.head(2)
# Out:
#                        address  \
# 0  2818 E Camino Acequia Drive
# 1         30 Eglinton Avenue W
#
#                                           attributes             business_id  \
# 0                           {'GoodForKids': 'False'}  1SWheh84yJXfytovILXOAQ
# 1  {'RestaurantsReservations': 'True', 'GoodForMe...  QXAEGFB4oINsVuTFxEYKFQ
#
#                                           categories         city  \
# 0                                  Golf, Active Life      Phoenix
# 1  Specialty Food, Restaurants, Dim Sum, Imported...  Mississauga
#
#                                                hours  is_open   latitude  \
# 0                                               None        0  33.522143
# 1  {'Monday': '9:0-0:0', 'Tuesday': '9:0-0:0', 'W...        1  43.605499
#
#     longitude                        name postal_code  review_count  stars  \
# 0 -112.018481  Arizona Biltmore Golf Club       85016             5    3.0
# 1  -79.652289  Emerald Chinese Restaurant     L5R 3E7           128    2.5
#
#   state
# 0    AZ
# 1    ON

# %%
yelp_shortened_df =  yelp_df[['name','city', 'state', 'latitude', 'longitude', 'stars']].set_index('state')
yelp_ffplaces= yelp_shortened_df.loc[['NC']]

# %%
US_cities_df=pd.read_csv("uscitiesv1.5.csv")

# %%
US_cities_df=US_cities_df[['city','state_id','county_name']]
NC_cities_df=US_cities_df[US_cities_df["state_id"] == "NC"].set_index("state_id").reset_index()
NC_cities_df.head(10)

NC_cities_df.set_index("city").join(yelp_ffplaces.set_index("city"), how = "right")
# Out:
#               state_id county_name                                    name  \
# city
# Ballantyne         NaN         NaN             LaVida Massage - Ballantyne
# Belmont             NC      Gaston        GiGi's Boutique Fine Consignment
# Belmont             NC      Gaston            The Belmont Drive-In Theater
# Belmont             NC      Gaston  Steve Davis Heating & Air Conditioning
# Belmont             NC      Gaston                             King Buffet
# Belmont             NC      Gaston                          Jean's Flowers
# Belmont             NC      Gaston            Friends Sports Bar and Grill
# Belmont             NC      Gaston    Johnny B's Pizza Pad & Watering Hole
# Belmont             NC      Gaston                                   Bi-Lo
# Belmont             NC      Gaston                       Papa John's Pizza
# Belmont             NC      Gaston                                     Jax
# Belmont             NC      Gaston                   Aquawave Express Wash
# Belmont             NC      Gaston                                Hardee's
# Belmont             NC      Gaston                  Simply Yoga of Belmont
# Belmont             NC      Gaston                         Seven Oaks Cafe
# Belmont             NC      Gaston                            CVS Pharmacy
# Belmont             NC      Gaston                     Glenway Premium Pub
# Belmont             NC      Gaston                  Muddy River Distillery
# Belmont             NC      Gaston                             Purdy Sweet
# Belmont             NC      Gaston                       Belmont Soda Shop
# Belmont             NC      Gaston            Four Seasons Car Wash Center
# Belmont             NC      Gaston                Catawba Fountain & Grill
# Belmont             NC      Gaston                            Sake Express
# Belmont             NC      Gaston                             Elite Nails
# Belmont             NC      Gaston                        Rivermen Brewing
# Belmont             NC      Gaston                           Beijing To Go
# Belmont             NC      Gaston                Rita's Family Restaurant
# Belmont             NC      Gaston         Catawba Heights Animal Hospital
# Belmont             NC      Gaston                                    ALDI
# Belmont             NC      Gaston                            MinuteClinic
# ...                ...         ...                                     ...
# Weddington          NC       Union                       Poppyseeds Bagels
# Weddington          NC       Union            Executive Swimming Pools Inc
# Weddington          NC       Union                           The UPS Store
# Weddington          NC       Union                        Modern Pet Salon
# Wesley Chapel       NC       Union                Anthony's Custom Jewelry
# Wesley Chapel       NC       Union                                PetSmart
# Wesley Chapel       NC       Union                    BracesPlus Dr Graham
# Wesley Chapel       NC       Union                           Harris Teeter
# Wesley Chapel       NC       Union                   Brooklyn Pizza Parlor
# Wesley Chapel       NC       Union           Carolina Pets Animal Hospital
# Wesley Chapel       NC       Union                               Villa Mia
# Wesley Chapel       NC       Union                                    TCBY
# Wesley Chapel       NC       Union                      Gréco Fresh Grille
# Wesley Chapel       NC       Union               Saveeda's American Bistro
# Wesley Chapel       NC       Union                      Forest Lake Dental
# Wesley Chapel       NC       Union                  Kami Chinese and Sushi
# Wesley Chapel       NC       Union                             201 Central
# Wesley Chapel       NC       Union                                 PostNet
# Wesley Chapel       NC       Union                              McDonald's
# Wesley Chapel       NC       Union          Larkin and the Pea Photography
# Wesley Chapel       NC       Union                Nail Spa Village Commons
# Wesley Chapel       NC       Union                              AT&T Store
# Wesley Chapel       NC       Union                          Hickory Tavern
# Wesley Chapel       NC       Union                                  Target
# Wesley Chapel       NC       Union                         Anytime Fitness
# Westport            NC     Lincoln                         A Taste of Soul
# charlotte          NaN         NaN                  Murphy's Kitchen & Tap
# charlotte          NaN         NaN                    Serenity Salon & Spa
# charlotte          NaN         NaN           Smith Environmental Solutions
# charlottte         NaN         NaN                              CMC Moving
#
#                 latitude  longitude  stars
# city
# Ballantyne     35.070495 -80.844518    4.0
# Belmont        35.243098 -81.037468    3.0
# Belmont        35.256886 -81.058174    4.0
# Belmont        35.242917 -81.037297    2.5
# Belmont        35.253526 -81.043641    1.5
# Belmont        35.245206 -81.031752    2.5
# Belmont        35.242931 -81.037641    3.0
# Belmont        35.244307 -81.037663    4.0
# Belmont        35.254387 -81.042170    3.0
# Belmont        35.254207 -81.041660    3.0
# Belmont        35.242924 -81.036897    2.5
# Belmont        35.252286 -81.046329    3.0
# Belmont        35.254110 -81.043594    3.0
# Belmont        35.243435 -81.037786    5.0
# Belmont        35.158752 -81.042963    3.5
# Belmont        35.251200 -81.029600    1.5
# Belmont        35.242924 -81.036897    4.0
# Belmont        35.236902 -81.014795    4.5
# Belmont        35.240751 -81.038493    5.0
# Belmont        35.243430 -81.038197    4.0
# Belmont        35.249668 -81.024138    3.5
# Belmont        35.243155 -81.028482    3.5
# Belmont        35.254232 -81.027777    3.5
# Belmont        35.251241 -81.044653    2.5
# Belmont        35.245150 -81.035173    3.5
# Belmont        35.281519 -81.047038    3.5
# Belmont        35.271441 -81.031147    5.0
# Belmont        35.264410 -81.026903    3.0
# Belmont        35.251747 -81.045715    4.0
# Belmont        35.251200 -81.029600    2.0
# ...                  ...        ...    ...
# Weddington     35.023509 -80.760826    3.5
# Weddington     35.023258 -80.760611    4.0
# Weddington     35.023288 -80.760687    1.0
# Weddington     35.026427 -80.763068    4.5
# Wesley Chapel  35.003129 -80.700002    4.0
# Wesley Chapel  34.998874 -80.694151    2.5
# Wesley Chapel  35.000649 -80.693743    5.0
# Wesley Chapel  35.000007 -80.699657    3.5
# Wesley Chapel  35.000667 -80.693754    3.0
# Wesley Chapel  34.999705 -80.699412    5.0
# Wesley Chapel  34.999927 -80.699440    3.5
# Wesley Chapel  35.000300 -80.697153    4.5
# Wesley Chapel  35.000617 -80.694074    4.5
# Wesley Chapel  34.999705 -80.699412    4.5
# Wesley Chapel  35.001633 -80.699073    5.0
# Wesley Chapel  34.999705 -80.699412    3.5
# Wesley Chapel  35.003118 -80.699897    4.0
# Wesley Chapel  34.999702 -80.699416    3.0
# Wesley Chapel  35.001520 -80.700541    1.5
# Wesley Chapel  35.007094 -80.674513    5.0
# Wesley Chapel  34.999609 -80.699256    2.5
# Wesley Chapel  34.999922 -80.698347    1.0
# Wesley Chapel  35.001381 -80.693298    3.0
# Wesley Chapel  34.999775 -80.695960    3.5
# Wesley Chapel  35.003391 -80.699403    5.0
# Westport       35.482849 -80.994714    4.0
# charlotte      35.230232 -80.847212    4.5
# charlotte      35.028656 -80.851142    4.5
# charlotte      35.310646 -80.797721    5.0
# charlottte     35.221262 -80.840431    4.0
#
# [14720 rows x 6 columns]
